# %% [markdown]
# # COMO HACER FIGURAS GEOMETRICAS Y CREACION DE LOS LENTES

# %% [markdown]
# ## FIGURAS GEOMETRICAS

# %%
import matplotlib.pyplot as plt
import numpy as np

# Crear el gráfico
fig, ax = plt.subplots()

# Establecer los límites del plano cartesiano
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

# Parámetros del lente
radio_curvatura = 1.5
espesor = 0.5

# Función para calcular el perfil del lente convergente
def perfil_lente_convergente(x):
    return np.sqrt(radio_curvatura**2 - x**2)#+ espesor /2

# Función para calcular el perfil del lente convergente invertido
def perfil_lente_convergente_invertido(x):
    return -np.sqrt(radio_curvatura**2 - x**2)#- espesor/2

# Rango de valores en el eje X
x = np.linspace(-radio_curvatura, radio_curvatura, 1000)

# Perfil del lente convergente
perfil_convergente = perfil_lente_convergente(x)

# Perfil del lente convergente invertido
perfil_convergente_invertido = perfil_lente_convergente_invertido(x)

# Dibujar el lente convergente
ax.plot(x, perfil_convergente, color='blue', label='Lente Convergente')
# Dibujar el lente convergente invertido
ax.plot(x, perfil_convergente_invertido, color='blue', label='Lente Convergente Invertido')

# Mostrar leyenda y etiquetas de los ejes
ax.legend()
ax.set_xlabel('Posición en el eje X')
ax.set_ylabel('Posición en el eje Y')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### figuras geometricas

# %%
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import matplotlib.patches as mpatches

fig = plt.figure()#se crea una nueva figura utilizando plt.figure(), que es un lienzo en blanco donde se pueden agregar subplots y otros elementos gráficos.
ax = fig.add_subplot(1, 1, 1)#se crea un suplot donde se usa la ubicacion 1 de 1 fila por una columna

'''
add_subplot(1, 1, 1), lo que significa lo siguiente:

    El primer argumento, 1, indica el número de filas de subplots en la figura. Aquí 
    se especifica que solo habrá una fila de subplots.

    El segundo argumento, 1, indica el número de columnas de subplots en la figura. Al
    igual que en el caso anterior, se especifica que solo habrá una columna de subplots.

    El tercer argumento, 1, indica el número de subplot específico que se está 
    agregando en la figura. Aquí se especifica que se está agregando el primer y 
    único subplot en la posición (1, 1) de la cuadrícula de subplots.


Es importante tener en cuenta que se pueden agregar múltiples subplots a una
figura utilizando diferentes combinaciones de argumentos en add_subplot(), como 
add_subplot(2, 2, 1) para crear una cuadrícula de 2x2 subplots y agregar un
subplot en la posición (1, 1).
'''

pp0 = plt.plot(1, 2, marker = 'o', color = 'red')#se crea un punto con .plot

plt.ylim(0,15)#limite de y
plt.xlim(0,15)#limite de x

plt.title('figuras geometricas')#agrega titulo
plt.grid()#agrega cuadriculas
plt.show()#muestra la gráfica(gráfica)

#para graficar un punto no es decesario el add.patches, se usa para agregar diferentes figuras

# %%
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import matplotlib.patches as mpatches

fig = plt.figure()#se crea una nueva figura utilizando plt.figure(), que es un lienzo en blanco donde se pueden agregar subplots y otros elementos gráficos.
ax = fig.add_subplot(1, 1, 1)

pp0 = plt.plot(1, 2, marker = 'o', color = 'red')
pp1 = plt.Rectangle((2, 10),6, 4, color = 'green')#se crea un rectangulo
pp2 = plt.Circle((12, 7), radius = 2, color = 'magenta')
pp3 = plt.Polygon([[8,5], [3,4], [5,8]], color = 'yellow')

ax.add_patch(pp1)
ax.add_patch(pp2)
ax.add_patch(pp3)


plt.ylim(0,15)
plt.xlim(0,15)

plt.title('figuras geometricas')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import matplotlib.patches as mpatches

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

pp0 = mpatches.Wedge((12, 7), 2, 90, 270, width=2, color='magenta')

ax.add_patch(pp0)

ax.set_ylim(0, 15)
ax.set_xlim(0, 15)

plt.title('Figuras geométricas')
plt.grid()
plt.show()

'''
En este caso, se utiliza la clase Wedge en lugar de Circle. El Wedge representa
una cuña en un gráfico circular y acepta los ángulos de inicio y final (theta1 y 
theta2) para definir la sección de la circunferencia a mostrar.
'''
# Out:
# '\nEn este caso, se utiliza la clase Wedge en lugar de Circle. El Wedge representa\nuna cuña en un gráfico circular y acepta los ángulos de inicio y final (theta1 y \ntheta2) para definir la sección de la circunferencia a mostrar.\n'

# %% [markdown]
# #### wedge
# La clase Wedge se utiliza para representar una cuña en un gráfico circular. Se
# define por su centro, radio, ángulo de inicio y ángulo final.
#
# wedge = mpatches.Wedge(center, radius, theta1, theta2, color='magenta')
#
# - center: Especifica las coordenadas (x, y) del centro de la cuña.
# - radius: Define el radio de la cuña.
# - theta1: Indica el ángulo de inicio en grados.
# - theta2: Indica el ángulo final en grados.
#
# set_aspect('equal') garantiza que el gráfico se muestre como un círculo.

# %% [markdown]
# ## CREACION DE LOS CODIGOS DE LOS LENTES

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

# Crear un Wedge
center = (0.5, 0.5)  # Coordenadas del centro de la cuña (x, y)
radius = 0.3  # Radio de la cuña
theta1 = 45  # Ángulo de inicio en grados
theta2 = 135  # Ángulo final en grados

wedge = mpatches.Wedge(center, radius, theta1, theta2, color='magenta')

# Agregar el Wedge al gráfico
ax.add_patch(wedge)

# Configurar límites y aspecto
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

plt.title('Ejemplo de Wedge')
plt.grid(True)
plt.show()

# %% [markdown]
# ### GRAFICANDO UN LENTE CONVERGENTE(PROCESO)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

# Crear Wedges
wedge_1 = mpatches.Wedge((-0.2, 0), 0.6, 0, 360, color='magenta')
wedge_2 = mpatches.Wedge((0.2, 0), 0.6, 0, 360, color='blue')

# Agregar el Wedge al gráfico
ax.add_patch(wedge_1)
ax.add_patch(wedge_2)

# Configurar límites y aspecto
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

plt.title('Intersección de Wedges')
plt.grid(True)
plt.show()

# %% [markdown]
# ### lente convergente

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

# Crear Wedges
wedge_1 = mpatches.Wedge((-49, 0), 55, 0, 360, color='magenta', alpha = 0)
wedge_2 = mpatches.Wedge((49, 0), 55, 0, 360, color='blue')
'''
alpha. Un valor de 0 indica transparencia total (completamente transparente) 
y un valor de 1 indica opacidad total (completamente sólido).
'''

# Agregar el Wedge al gráfico
ax.add_patch(wedge_1)
ax.add_patch(wedge_2)

# Recortar una cuña con la otra para mostrar la intersección
wedge_2.set_clip_path(wedge_1)

# Configurar límites y aspecto
ax.set_xlim(-70, 70)
ax.set_ylim(-70, 70)
ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

plt.title('Intersección de Wedges')
plt.grid(True)
plt.show()

# %% [markdown]
# ### GRAFICANDO UN LENTE DIVERGENTE(PROCESO)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

# Crear Wedges
wedge_1 = mpatches.Wedge((-0.7, 0), 0.6, 0, 360, color='magenta', alpha = 1)
wedge_2 = mpatches.Wedge((0.7, 0), 0.6, 0, 360, color='blue')

#crear primer cuadrado
cuadrado_1 = plt.Polygon([[-0.5,0.5], [-0.5,1], [0.5,1], [0.5,0.5]], color = 'yellow')
cuadrado_2 = plt.Polygon([[-0.5,-0.5], [-0.5,-1], [0.5,-1], [0.5,-0.5]], color = 'yellow')

# Agregar el Wedge al gráfico
ax.add_patch(cuadrado_1)
ax.add_patch(cuadrado_2)
ax.add_patch(wedge_1)
ax.add_patch(wedge_2)

# Configurar límites y aspecto
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

plt.title('Intersección de Wedges')
plt.grid(True)
plt.show()

# %% [markdown]
# ### lente divergente

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

# Crear Wedges
wedge_1 = mpatches.Wedge((-57, 0), 55, 0, 360, color='white', alpha = 1)
wedge_2 = mpatches.Wedge((57, 0), 55, 0, 360, color='white')

#crear primer cuadrado
cuadrado_1 = plt.Polygon([[-20,-24.8], [-20,24.8], [20,24.8], [20,-24.8]], color = 'blue')

# Agregar el Wedge al gráfico
ax.add_patch(cuadrado_1)
ax.add_patch(wedge_1)
ax.add_patch(wedge_2)

# # Recortar una cuña con la otra para mostrar la intersección
# wedge_2.set_clip_path(cuadrado_1)
# wedge_1.set_clip_path(cuadrado_1)

# Configurar límites y aspecto
ax.set_xlim(-70, 70)
ax.set_ylim(-70, 70)
ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

plt.title('Intersección de Wedges')
plt.grid(True)
plt.show()

# %% [markdown]
# ### subplot
#  un subplot se refiere a la división de una figura o gráfico en varias subfiguras más pequeñas. La biblioteca matplotlib es comúnmente utilizada para crear subplots en Python.

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 8, 27, 64]

# Crear los subplots
fig, (ax1, ax2) = plt.subplots(2)

# Subplot 1
ax1.plot(x, y1)
ax1.set_title('Subplot 1')
ax1.set_xlabel('X')
ax1.set_ylabel('Y1')

# Subplot 2
ax2.plot(x, y2)
ax2.set_title('Subplot 2')
ax2.set_xlabel('X')
ax2.set_ylabel('Y2')

# Mostrar los subplots
plt.tight_layout()
plt.show()

'''
 En este ejemplo, se crea una figura que contiene dos subfiguras (subplots). Cada
 subfigura se representa mediante un objeto Axes en matplotlib, que se almacena en
 las variables ax1 y ax2. Luego, se trazan las líneas correspondientes a los datos 
 y1 e y2 en cada subfigura, y se establecen los títulos y etiquetas adecuados para
 cada eje.

 El método plt.subplots(2) crea una figura con 2 subplots apilados verticalmente.
 Si se desea una disposición diferente, se pueden especificar otros argumentos en
 subplots(), como plt.subplots(1, 2) para dos subplots en una fila o
 plt.subplots(2, 2) para una matriz de 2x2 subplots, entre otras opciones.
 '''
# Out:
# '\n En este ejemplo, se crea una figura que contiene dos subfiguras (subplots). Cada\n subfigura se representa mediante un objeto Axes en matplotlib, que se almacena en\n las variables ax1 y ax2. Luego, se trazan las líneas correspondientes a los datos \n y1 e y2 en cada subfigura, y se establecen los títulos y etiquetas adecuados para\n cada eje.\n\n El método plt.subplots(2) crea una figura con 2 subplots apilados verticalmente.\n Si se desea una disposición diferente, se pueden especificar otros argumentos en\n subplots(), como plt.subplots(1, 2) para dos subplots en una fila o\n plt.subplots(2, 2) para una matriz de 2x2 subplots, entre otras opciones.\n '

# %% [markdown]
# ### PAR DE LENTES

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def par_de_lentes():
    
    fig, ax = plt.subplots()

    # #en donde está el lente, ubicación en x
    # adision = float(input('ingrese la coordenada en x de el lente convergente: ').strip())

    # componentes lente convergente
    wedge_1 = mpatches.Wedge((-49, 0), 55, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge((49, 0), 55, 0, 360, color='blue')

    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)

    # componentes de el lente divergente
    wedge_3 = mpatches.Wedge((-57, 0), 55, 0, 360, color='white', alpha = 0.5)
    wedge_4 = mpatches.Wedge((57, 0), 55, 0, 360, color='white', alpha = 0.5)

    #crear primer cuadrado
    cuadrado_1 = plt.Polygon([[-8,-24.8], [-8,24.8], [8,24.8], [8,-24.8]], color = 'blue', alpha = 0.8)

    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_3)
    ax.add_patch(wedge_4)

    # Configurar límites y aspecto
    ax.set_xlim(-100, 100)
    ax.set_ylim(-100, 100)
    ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

    plt.title('Intersección de Wedges')
    plt.grid(True)
    plt.show()

par_de_lentes()

# %% [markdown]
# ### el usuario ingresa los datos

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def par_de_lentes():    
    fig, ax = plt.subplots()

    # distancia del primer lente
    d_c = int(input("a que distancia esta el primer lente del objeto?\n").strip())

    # distancia del segundo lente
    d_d = int(input("a que distancia esta el segundo lente del objeto?\n ").strip())

    # componentes lente convergente
    wedge_1 = mpatches.Wedge((-49+d_c, 0), 55, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge((49+d_c, 0), 55, 0, 360, color='blue')

    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)

    # componentes de el lente divergente
    wedge_3 = mpatches.Wedge((-57+d_d, 0), 55, 0, 360, color='white', alpha = 0.5)
    wedge_4 = mpatches.Wedge((57+d_d, 0), 55, 0, 360, color='white', alpha = 0.5)

    #cuadrado componente de el lente divergente
    cuadrado_1 = plt.Polygon([[-8+d_d,-24.8], [-8+d_d,24.8], [8+d_d,24.8], [8+d_d,-24.8]], color = 'blue', alpha = 0.8)

    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_3)
    ax.add_patch(wedge_4)

    #eje "x" y eje "y"
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal


    # Configurar límites y aspecto
    ax.set_xlim(-100, 100)
    ax.set_ylim(-100, 100)
    ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

    plt.title('Intersección de Wedges')
    plt.grid(True)
    plt.show()

par_de_lentes()

# %%
def par_de_lentes():    
    fig, ax = plt.subplots()

    # distancia del primer lente
    d_c = int(input("a que distancia esta el primer lente del objeto?\n").strip())

    # distancia del segundo lente
    d_d = int(input("a que distancia esta el segundo lente del objeto?\n ").strip())

    # componentes lente convergente
    wedge_1 = mpatches.Wedge((-49+d_c, 0), 55, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge((49+d_c, 0), 55, 0, 360, color='aquamarine')

    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)

    # componentes de el lente divergente
    wedge_3 = mpatches.Wedge((-57+d_d, 0), 55, 0, 360, color='white', alpha = 1)
    wedge_4 = mpatches.Wedge((57+d_d, 0), 55, 0, 360, color='white', alpha = 1)

    #cuadrado componente de el lente divergente
    cuadrado_1 = plt.Polygon([[-8+d_d,-24.8], [-8+d_d,24.8], [8+d_d,24.8], [8+d_d,-24.8]], color = 'blue', alpha = 0.8)

    # Agregar el Wedge al gráfico
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_3)
    ax.add_patch(wedge_4)
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    #eje "x" y eje "y"
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal


    # Configurar límites y aspecto
    ax.set_xlim(-100, 100)
    ax.set_ylim(-100, 100)
    ax.set_aspect('equal')  # Para asegurar que se grafique como un círculo

    plt.title('Intersección de Wedges')
    plt.grid(True)
    plt.show()

par_de_lentes()

# %% [markdown]
# ### rayos principales

# %% [markdown]
# ##### como graficar vectores

# %%
import matplotlib.pyplot as plt

def grafica_vectores():
    # Coordenadas de los vectores
    x = [1]
    y = [2]

    # Crear una figura y ejes
    fig, ax = plt.subplots()

    # Graficar los vectores
    ax.quiver(0, 0, x, y, angles='xy', scale_units='xy', scale=1, color = 'green')

    # Configurar límites y aspecto del gráfico
    ax.set_xlim([-1, 3])
    ax.set_ylim([-1, 3])
    ax.set_aspect('equal')

    #eje "x" y eje "y"
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal

    # Etiquetas y título
    ax.set_xlabel('Eje x')
    ax.set_ylabel('Eje y')
    ax.set_title('Vectores en el plano')

    # Mostrar el gráfico
    plt.grid(True)
    plt.show()

# Llamar a la función para graficar los vectores
grafica_vectores()

# %% [markdown]
# #### rayos

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

f = 5
d = 20
h = 3
foco = [d-f,0]

if h != 0:
    # Agregar los rayos principales incidentes
    plt.plot([0, h], [0, h], color='red', linewidth=1)
    plt.plot([0, d-f], [h, 0], color='green', linewidth=1)
    plt.plot([0, -57+d+40], [0, -40], color='blue', linewidth=1)


elif d == f:
    # Agregar los rayos principales incidentes
    plt.plot([0, d], [0, 12], color='red', linewidth=1)
    plt.plot([0, d], [0, 0], color='green', linewidth=1)
    plt.plot([0, d], [0, -12], color='blue', linewidth=1) 

    # Agregar los rayos principales emergentes
    plt.plot([d, 300], [12, 12], color='red', linewidth=1)
    plt.plot([d, 300], [0, 0], color='green', linewidth=1)
    plt.plot([d, 300], [-12, -12], color='blue', linewidth=1) 

#punto focal
plt.plot(d-f, 0, marker = 'o', color = 'k')

# Agregar las líneas con alto valor de zorder
plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal

# Configurar límites y aspecto
ax.set_xlim(-10, 50)
ax.set_ylim(-25, 25)
ax.set_aspect('equal')

plt.title('Sistema de lente convergente')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

def rayos_incidentes(f, d, h, foco,imagen):
    if h != 0:
        #rayo paralelo
        plt.plot([0, d], [h, h], color = 'red', linewidth = 1)

        # pendiente del rayo que pasa por el foco
        x1, y1 = [0, foco[0]], [h, 0]
        m = (y1[1] - y1[0]) / (x1[1] - x1[0])
        # rayo que pasa por el foco
        x2 = [0, d]
        y2 = [h, h + m * (x2[1] - x2[0])]
        plt.plot(x2, y2, color='green', linewidth=1)

        #recta que pasa por el centro
        plt.plot([0, d], [h, 0], color='blue', linewidth=1)

    else:
        if d == f:
            plt.plot([0, d], [0, 0], color='red', linewidth=1)
            plt.plot([0, d], [0, 14], color='green', linewidth=1)
            plt.plot([0, d], [0, -14], color='blue', linewidth=1)

    #eje "x" y eje "y"
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal
    
    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')

    #agrego rayos emergentes
    rayos_emergentes(f, d, h, foco,imagen)
    plt.show()

def rayos_emergentes(f, d, h, foco, imagen):
    magnificacion = d/imagen
    altura_imagen = h*magnificacion
    if h != 0:
        #rayo que pasa por el foco emerge paralelo
        plt.plot([d, d+imagen], [-h, -h], color = 'green', linewidth = 1)

        # pendiente del rayo que emerge por el foco
        x1, y1 = [0, foco[0]], [h, 0]
        m = -(y1[1] - y1[0]) / (x1[1] - x1[0])
        # rayo que emerge por el foco
        x2 = [d, d + imagen]
        y2 = [h, h - m * (x2[1] - x2[0])]
        plt.plot(x2, y2, color='red', linewidth=1)

        #recta que pasa por el centro sigue por el centro hata la imagen
        plt.plot([d, d+imagen], [0, -h], color='blue', linewidth=1)

    else:
        if d == f:
            plt.plot([d, d+f], [14, 0], color='red', linewidth=1)
            plt.plot([d, d+f], [0, 0], color='green', linewidth=1)
            plt.plot([d, d+f], [-14, 0], color='blue', linewidth=1)

    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')
    plt.show()

f = 5#int(input('ingrese el foco de el lente\n')) #distancia focal
d = 10#int(input('a que distancia esta el lente del objeto?\n')) #a que distancia esta el lente?
h = 3#int(input('a que altura respecto al eje axial esta ubicado el objeto?\n')) #altura de el lente
foco = [d-f, 0] #coordenada del foco
imagen = 1/((1/f)-(1/d))

rayos_incidentes(f, d, h, foco, imagen)

# %% [markdown]
# ### rayos emergentes y el lente convergente

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def magnificacion(d, imagen):
    magnificacion = d/imagen
    altura_imagen= h*magnificacion
    return(altura_imagen)

def grafica_lente_convergente(f, d, h, foco, imagen):
    fig, ax = plt.subplots()
    
    # Crear Wedges{cuñás}
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-(R/2)+d, 0), R, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge(((R/2)+d, 0), R, 0, 360, color='aquamarine')
    
    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)
    
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente convergente.')
    plt.grid(True)
    plt.legend()
    
    #agrego los rayos
    rayos_incidentes(f, d, h, foco,imagen)

def rayos_incidentes(f, d, h, foco,imagen):
    if h != 0:
        #rayo paralelo
        plt.plot([0, d], [h, h], color = 'red', linewidth = 1)

        # pendiente del rayo que pasa por el foco
        x1, y1 = [0, foco[0]], [h, 0]
        m = (y1[1] - y1[0]) / (x1[1] - x1[0])
        # rayo que pasa por el foco
        x2 = [0, d]
        y2 = [h, h + m * (x2[1] - x2[0])]
        plt.plot(x2, y2, color='green', linewidth=1)

        #recta que pasa por el centro
        plt.plot([0, d], [h, 0], color='blue', linewidth=1)

    else:
        if d == f:
            plt.plot([0, d], [0, 0], color='red', linewidth=1)
            plt.plot([0, d], [0, 14], color='green', linewidth=1)
            plt.plot([0, d], [0, -14], color='blue', linewidth=1)

    #eje "x" y eje "y"
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal
    
    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')

    #agrego rayos emergentes
    rayos_emergentes(f, d, h, foco, imagen)

    plt.show()

def rayos_emergentes(f, d, h, foco, imagen):
    if h != 0:
        #rayo que pasa por el foco emerge paralelo
        plt.plot([d, d+imagen], [-h, -h], color = 'green', linewidth = 1)

        # pendiente del rayo que emerge por el foco
        x1, y1 = [0, foco[0]], [h, 0]
        m = -(y1[1] - y1[0]) / (x1[1] - x1[0])
        # rayo que emerge por el foco
        x2 = [d, d + imagen]
        y2 = [h, h - m * (x2[1] - x2[0])]
        plt.plot(x2, y2, color='red', linewidth=1)

        #recta que pasa por el centro sigue por el centro hata la imagen
        plt.plot([d, d+imagen], [0, -h], color='blue', linewidth=1)

    else:
        if d == f:
            plt.plot([d, d+f], [14, 0], color='red', linewidth=1)
            plt.plot([d, d+f], [0, 0], color='green', linewidth=1)
            plt.plot([d, d+f], [-14, 0], color='blue', linewidth=1)

    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')
    plt.show()

f = 5#int(input('ingrese el foco de el lente\n')) #distancia focal
d = 10#int(input('a que distancia esta el lente del objeto?\n')) #a que distancia esta el lente?
h = 3#int(input('a que altura respecto al eje axial esta ubicado el objeto?\n')) #altura de el lente
foco = [d-f, 0] #coordenada del foco
imagen = 1/((1/f)-(1/d))

grafica_lente_convergente(f, d, h, foco, imagen)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def grafica_lente_convergente(d):
    fig, ax = plt.subplots()

    # Crear Wedges{cuñás}
    wedge_1 = mpatches.Wedge((-49+d, 0), 55, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge((49+d, 0), 55, 0, 360, color='aquamarine')
    
    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)

    # Configurar límites y aspecto
    ax.set_xlim(-30, 30)
    ax.set_ylim(-30, 30)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente

    plt.title('sistema de lente convergente.')
    plt.grid(True)
    plt.show()

grafica_lente_convergente(8)

# %% [markdown]
# ### rayos incidentes y lente divergente

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from sympy import oo

def magnificacion(d, imagen):
    magnificacion = d/imagen
    altura_imagen= h*magnificacion
    return(altura_imagen)

def grafica_lente_convergente(f, d, h, imagen):
    fig, ax = plt.subplots()
    
    # Crear Wedges{cuñás}
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-(R/2)+d, 0), R, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge(((R/2)+d, 0), R, 0, 360, color='aquamarine')
    
    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10, linewidth=0.7)  # Línea horizontal

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)
    
    ax.autoscale(tight=True)
    # ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente convergente.')
    # plt.grid(True) #agregar divisiones
    plt.legend()
    
    ax.set_xlim(d-f-3, d+f+3)
    ax.set_ylim(-h, h)
    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)

def grafica_lente_divergente(f, d, h, imagen):
    fig, ax = plt.subplots()

    # Crear Wedges
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    print(4*R)
    wedge_1 = mpatches.Wedge((-R-0.5+d, 0), R, 0, 360, color='white')
    wedge_2 = mpatches.Wedge((R+0.5+d, 0), R, 0, 360, color='white')

    #crear cuadrado
    cuadrado_1 = plt.Polygon([[-3.85+d,-3.85], [-3.85+d,3.85], [3.85+d,3.85], [3.85+d,-3.85]], color = 'blue')

    # Agregar el Wedge al gráfico
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    plt.axvline(x=0, color='k', zorder=10, linewidth=0.7)  # Línea vertical
    # plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal

    #autoescala
    # ax.autoscale(tight=True)
    ax.set_xlim(d-f-3, d+f+3)
    ax.set_ylim(h-10, h+5)
    #ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente


    ax.set_xlim(-d-f-3, d+f+3)
    ax.set_ylim(-h, h)

    plt.title('sistema de lente divergente.')
    plt.grid(True)
    plt.show()

    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)


def rayos_incidentes(f, d, h,imagen):
    #rayo paralelo
    plt.plot([0, d], [h, h], color = 'red', linewidth = 2.5)

    # pendiente del rayo que pasa por el foco
    x1, y1 = [0, d-f], [h, 0]
    try:
        m_f = (y1[1] - y1[0]) / (x1[1] - x1[0])
    
    except ZeroDivisionError:
        m_f=-500
        print('imagen en el infinito')
    # rayo que pasa por el foco
    x2 = [0, d]
    y2 = [h, h + m_f * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='green', linewidth=2.5)

    # recta vertical en x=d
    x3 = [d, d]
    y3 = [-50, 50]
    plt.plot(x3, y3, color='k', linewidth=0.5, linestyle = '--')

    # cálculo de la intersección
    xi = d
    yi = y2[0] + m_f * (xi - x2[0])
    interseccion = [xi, yi]

    # pendiente de la recta que pasa por el centro
    x1, y1 = [0, d], [h, 0]
    try:
        m_c = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_c = float('inf')
        print('Pendiente infinita')

    # recta que pasa por el centro
    x2 = [0, d]
    y2 = [h, h + m_c * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='blue', linewidth=2.5)
    
    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')

    # vector de altura h ubicado en el origen
    plt.quiver(0, 0, 0, h, angles='xy', scale_units='xy', scale=1, color='yellow')

    #agrego rayos emergentes
    rayos_emergentes(f, d, h, imagen, interseccion, m_c, )

    plt.show()

def rayos_emergentes(f, d, h, imagen, list, m_centro):
    #rayo que pasa por el foco emerge paralelo
    plt.plot([d, d+50], [list[1], list[1]], color = 'green', linewidth = 2.5)

    #proyeccion del rayo que pasa por el foco emerge paralelo
    plt.plot([-200, 200], [list[1], list[1]], color = 'green', linewidth = 2.5, linestyle = '--')
    
    # pendiente del rayo que emerge por el foco
    x1, y1 = [d, d+f], [h, 0]
    try:
        m = -(y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m=-500
        print('imagen en el infinito')

    # rayo que emerge por el foco
    x2 = [d, d + 50]
    y2 = [h, h - m * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='red', linewidth=2.5)

    # proyeccion del rayo que emerge por el foco
    x4 = [-200, 200]
    y4 = [h - m * (x4[0] - d), h - m * (x4[1] - d)]
    plt.plot(x4, y4, color='red', linewidth=2.5, linestyle = '--')

    # rayo que emerge por el centro
    x_c= [d, d+50]
    y_c = [0, m_centro * (x_c[1] - x_c[0])]
    plt.plot(x_c, y_c, color='blue', linewidth=2.5)
    
    # proyeccion de el rayo que emerge por el centro
    x5 = [-200, 200]
    y5 = [ m_centro * (x5[0] - d), 0 + m_centro * (x5[1] - d)]
    plt.plot(x5, y5, color='blue', linewidth=2.5, linestyle = '--')

    # Ecuación de la línea que emerge por el foco
    m1 = (y4[1] - y4[0]) / (x4[1] - x4[0])
    b1 = y4[0] - m1 * x4[0]

    # Ecuación del rayo que emerge por el centro
    m2 = (y5[1] - y5[0]) / (x5[1] - x5[0])
    b2 = y5[0] - m2 * x5[0]

    # Resolviendo para x
    try:
        x_intersect = (b2 - b1) / (m1 - m2)
        # Resolviendo para y
        y_intersect = m1 * x_intersect + b1

    except ZeroDivisionError:
        x_intersect = 0
        # Resolviendo para y
        y_intersect = 0

    #vector altura de la imagen
    plt.quiver(x_intersect, 0, 0, y_intersect, angles='xy', scale_units='xy', scale=1)

    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')
    plt.show()

f = 5#int(input('ingrese el foco de el lente\n')) #distancia focal
d = 10#int(input('a que distancia esta el lente del objeto?\n')) #a que distancia esta el lente?
h = 5#int(input('a que altura respecto al eje axial esta ubicado el objeto?\n')) #altura de el lente
try:
    imagen = 1/((1/f)-(1/d))
except ZeroDivisionError:
    imagen = 0
grafica_lente_convergente(f, d, h, imagen)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def grafica_lente_divergente(f, d, h, foco, imagen):
    fig, ax = plt.subplots()

    # Crear Wedges
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    print(4*R)
    wedge_1 = mpatches.Wedge((-R-0.5+d, 0), R, 0, 360, color='white')
    wedge_2 = mpatches.Wedge((R+0.5+d, 0), R, 0, 360, color='white')

    #crear cuadrado
    cuadrado_1 = plt.Polygon([[-3.85+d,-3.85], [-3.85+d,3.85], [3.85+d,3.85], [3.85+d,-3.85]], color = 'blue')

    # Agregar el Wedge al gráfico
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal

    #autoescala
    ax.autoscale(tight=True)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente

    plt.title('sistema de lente divergente.')
    plt.grid(True)
    plt.show()

f = 5#int(input('ingrese el foco de el lente\n')) #distancia focal
d = 10#int(input('a que distancia esta el lente del objeto?\n')) #a que distancia esta el lente?
h = 3#int(input('a que altura respecto al eje axial esta ubicado el objeto?\n')) #altura de el lente
foco = [d-f, 0] #coordenada del foco
imagen = 1/((1/f)-(1/d))

grafica_lente_divergente(f, d, h, foco, imagen)
# Out:
# 17.85199925921521

# %% [markdown]
# # LENTES CONVERGENTE Y DIVERGENTE CON SUS RESPECTIVOS RAYOS

# %% [markdown]
# ### terminado, lente convergente en distancia 'd'

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def magnificacion(d, imagen):
    magnificacion = d/imagen
    altura_imagen= h*magnificacion
    return(altura_imagen)

def grafica_lente_convergente(f, d, h, imagen):
    fig, ax = plt.subplots()
    
    # Crear Wedges{cuñás}
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-(R/2)+d, 0), R, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge(((R/2)+d, 0), R, 0, 360, color='aquamarine')
    
    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10, linewidth=0.7)  # Línea horizontal

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)
    
    ax.autoscale(tight=True)
    # ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente convergente.')
    # plt.grid(True) #agregar divisiones

    ax.set_xlim(-2-abs(imagen), abs(imagen)+d+abs(f))
    ax.set_ylim(-abs(h)-5, abs(h)+5)
    
    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)

def grafica_lente_divergente(f, d, h, imagen):
    fig, ax = plt.subplots()

    # Crear Wedges
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    print(4*R)
    wedge_1 = mpatches.Wedge((-R-0.5+d, 0), R, 0, 360, color='white')
    wedge_2 = mpatches.Wedge((R+0.5+d, 0), R, 0, 360, color='white')

    #crear cuadrado
    cuadrado_1 = plt.Polygon([[-3.85+d,-3.85], [-3.85+d,3.85], [3.85+d,3.85], [3.85+d,-3.85]], color = 'blue')

    # Agregar el Wedge al gráfico
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    plt.axvline(x=0, color='k', zorder=10, linewidth=0.7)  # Línea vertical
    # plt.axhline(y=0, color='k', zorder=10)  # Línea horizontal

    #autoescala
    # ax.autoscale(tight=True)
    #ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente

    #escala
    ax.set_xlim(-2-abs(imagen), abs(imagen)+d+abs(f))
    ax.set_ylim(-abs(h)-5, abs(h)+5)

    plt.title('sistema de lente divergente.')
    plt.grid(True)
    plt.show()

    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)


def rayos_incidentes(f, d, h,imagen):
    #rayo paralelo
    plt.plot([0, d], [h, h], color = 'red', linewidth = 2.5)

    # pendiente del rayo que pasa por el foco
    x1, y1 = [0, d-f], [h, 0]
    try:
        m_f = (y1[1] - y1[0]) / (x1[1] - x1[0])
    
    except ZeroDivisionError:
        m_f=-500
        print('imagen en el infinito')
    # rayo que pasa por el foco
    x2 = [0, d]
    y2 = [h, h + m_f * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='green', linewidth=2.5)

    # recta vertical en x=d
    x3 = [d, d]
    y3 = [-50, 50]
    plt.plot(x3, y3, color='k', linewidth=0.5, linestyle = '--')

    # cálculo de la intersección
    xi = d
    yi = y2[0] + m_f * (xi - x2[0])
    interseccion = [xi, yi]

    # pendiente de la recta que pasa por el centro
    x1, y1 = [0, d], [h, 0]
    try:
        m_c = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_c = float('inf')
        print('Pendiente infinita')

    # recta que pasa por el centro
    x2 = [0, d]
    y2 = [h, h + m_c * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='blue', linewidth=2.5)
    
    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')

    # vector de altura h ubicado en el origen
    plt.quiver(0, 0, 0, h, angles='xy', scale_units='xy', scale=1, color='yellow')

    #agrego rayos emergentes
    rayos_emergentes(f, d, h, imagen, interseccion, m_c, )

    plt.show()

def rayos_emergentes(f, d, h, imagen, list, m_centro):
    #rayo que pasa por el foco emerge paralelo
    plt.plot([d, d+50], [list[1], list[1]], color = 'green', linewidth = 2.5)

    #proyeccion del rayo que pasa por el foco emerge paralelo
    plt.plot([-200, 200], [list[1], list[1]], color = 'green', linewidth = 2.5, linestyle = '--')
    
    # pendiente del rayo que emerge por el foco
    x1, y1 = [d, d+f], [h, 0]
    try:
        m = -(y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m=-500
        print('imagen en el infinito')

    # rayo que emerge por el foco
    x2 = [d, d + 50]
    y2 = [h, h - m * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='red', linewidth=2.5)

    # proyeccion del rayo que emerge por el foco
    x4 = [-200, 200]
    y4 = [h - m * (x4[0] - d), h - m * (x4[1] - d)]
    plt.plot(x4, y4, color='red', linewidth=2.5, linestyle = '--')

    # rayo que emerge por el centro
    x_c= [d, d+50]
    y_c = [0, m_centro * (x_c[1] - x_c[0])]
    plt.plot(x_c, y_c, color='blue', linewidth=2.5)
    
    # proyeccion de el rayo que emerge por el centro
    x5 = [-200, 200]
    y5 = [ m_centro * (x5[0] - d), 0 + m_centro * (x5[1] - d)]
    plt.plot(x5, y5, color='blue', linewidth=2.5, linestyle = '--')

    # Ecuación de la línea que emerge por el foco
    m1 = (y4[1] - y4[0]) / (x4[1] - x4[0])
    b1 = y4[0] - m1 * x4[0]

    # Ecuación del rayo que emerge por el centro
    m2 = (y5[1] - y5[0]) / (x5[1] - x5[0])
    b2 = y5[0] - m2 * x5[0]

    # Resolviendo para x
    try:
        x_intersect = (b2 - b1) / (m1 - m2)
        # Resolviendo para y
        y_intersect = m1 * x_intersect + b1

    except ZeroDivisionError:
        x_intersect = 0
        # Resolviendo para y
        y_intersect = 0

    #vector altura de la imagen
    plt.quiver(x_intersect, 0, 0, y_intersect, angles='xy', scale_units='xy', scale=1)

    #punto focal
    plt.plot(d-f, 0, marker = 'o', color = 'k')
    plt.plot(d+f, 0, marker = 'o', color = 'k')
    plt.show()

f = 5#int(input('ingrese el foco de el lente\n')) #distancia focal
d = 1200#int(input('a que distancia esta el lente del objeto?\n')) #a que distancia esta el lente?
h = 9#int(input('a que altura respecto al eje axial esta ubicado el objeto?\n')) #altura de el lente

try:
    imagen = 1/((1/f)-(1/d))
    print(imagen)
except ZeroDivisionError:
    imagen = -f

grafica_lente_convergente(f, d, h, imagen)
# Out:
# 5.02092050209205

# %% [markdown]
# ### lente convergente ubicado en el cero

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def magnificacion(f, d, h, imagen):
    magnificacion = -imagen/d
    altura_imagen= h*magnificacion
    print(f'la magnificacion es: {magnificacion}')
    if f>0:
        grafica_lente_convergente(f, d, h, imagen, altura_imagen)
    elif f<0:
        grafica_lente_divergente(f, d, h, imagen, altura_imagen)
    else:
        print('como que cero mamahuevo!, digo glu,glu,glu,glu,glu')

def grafica_lente_convergente(f, d, h, imagen, altura_imagen):
    fig, ax = plt.subplots()
    
    # Crear Wedges{cuñás}
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-(R/2), 0), R, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge(((R/2), 0), R, 0, 360, color='aquamarine')
    
    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10, linewidth=0.7)  # Línea horizontal

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)
    
    #escala
    # ax.autoscale(tight=True)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente convergente.')

    ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)

    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)



def grafica_lente_divergente(f, d, h, imagen, altura_imagen):
    fig, ax = plt.subplots()

    # Crear Wedges
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    print(4*R)
    wedge_1 = mpatches.Wedge((-R-0.5, 0), R, 0, 360, color='white')
    wedge_2 = mpatches.Wedge((R+0.5, 0), R, 0, 360, color='white')

    #crear cuadrado
    cuadrado_1 = plt.Polygon([[-3.85,-3.85], [-3.85,3.85], [3.85,3.85], [3.85,-3.85]], color = 'blue')

    # Agregar el Wedge al gráfico
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10, linewidth=0.7)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=0.7)  # Línea horizontal

    #escala
    # ax.autoscale(tight=True)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente divergente.')

    ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)

    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)


def rayos_incidentes(f, d, h,imagen):
    #rayo paralelo
    plt.plot([-abs(d), 0], [h, h], color = 'red', linewidth = 2.5)

    # pendiente del rayo que pasa por el foco
    x1, y1 = [-abs(d), -abs(f)], [h, 0]
    try:
        m_f = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_f=-500
        print('imagen en el infinito')

    # rayo que pasa por el foco
    x2 = [-abs(d), 0]
    y2 = [h, h + m_f * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='green', linewidth=2.5)

    # recta vertical en x=d
    x3 = [0,0]
    y3 = [-50, 50]
    plt.plot(x3, y3, color='k', linewidth=0.5, linestyle = '--')

    # cálculo de la intersección
    xi = 0
    yi = y2[0] + m_f * (xi - x2[0])
    interseccion = [xi, yi]

    # pendiente de la recta que pasa por el centro
    x1, y1 = [0, d], [h, 0]
    try:
        m_c = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_c = float('inf')
        print('Pendiente infinita')

    # recta que pasa por el centro
    x2 = [-d, 0]
    y2 = [h, h + m_c * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='blue', linewidth=2.5)
    
    #punto focal
    plt.plot(-abs(f), 0, marker = 'o', color = 'k')
    plt.plot(abs(f), 0, marker = 'o', color = 'k')

    # vector de altura h ubicado en el origen
    plt.quiver(-abs(d), 0, 0, h, angles='xy', scale_units='xy', scale=1, color='yellow')

    #agrego rayos emergentes
    rayos_emergentes(f, d, h, imagen, interseccion, m_c)

    plt.show()


def rayos_emergentes(f, d, h, imagen, list, m_centro):
    #rayo que pasa por el foco emerge paralelo
    plt.plot([-0, d+100], [list[1], list[1]], color = 'green', linewidth = 2.5)

    #proyeccion del rayo que pasa por el foco emerge paralelo
    plt.plot([-200, 200], [list[1], list[1]], color = 'green', linewidth = 2.5, linestyle = '--')
    
    # pendiente del rayo que emerge por el foco
    x1, y1 = [0, f], [h, 0]
    try:
        m = -(y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m=-500
        print('imagen en el infinito')

    # rayo que emerge por el foco
    x2 = [0, d + 50]
    y2 = [h, h - m * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='red', linewidth=2.5)

    # proyeccion del rayo que emerge por el foco
    x4 = [-200, 200]
    y4 = [h - m * (x4[0]), h - m * (x4[1])]
    plt.plot(x4, y4, color='red', linewidth=2.5, linestyle = '--')

    # rayo que emerge por el centro
    x_c= [0, d+50]
    y_c = [0, m_centro * (x_c[1] - x_c[0])]
    plt.plot(x_c, y_c, color='blue', linewidth=2.5)
    
    # proyeccion de el rayo que emerge por el centro
    x5 = [-200, 200]
    y5 = [ m_centro * (x5[0]), 0 + m_centro * (x5[1])]
    plt.plot(x5, y5, color='blue', linewidth=2.5, linestyle = '--')

    # Ecuación de la línea que emerge por el foco
    m1 = (y4[1] - y4[0]) / (x4[1] - x4[0])
    b1 = y4[0] - m1 * x4[0]

    # Ecuación del rayo que emerge por el centro
    m2 = (y5[1] - y5[0]) / (x5[1] - x5[0])
    b2 = y5[0] - m2 * x5[0]

    # Resolviendo para x
    try:
        x_intersect = (b2 - b1) / (m1 - m2)
        # Resolviendo para y
        y_intersect = m1 * x_intersect + b1

    except ZeroDivisionError:
        x_intersect = 0
        # Resolviendo para y
        y_intersect = 0

    #vector altura de la imagen
    plt.quiver(x_intersect, 0, 0, y_intersect, angles='xy', scale_units='xy', scale=1)
    print(f'la altura del objeto: {h}\n',f'altura de la imagen: {y_intersect}' if y_intersect != 0 else '') 

    #punto focal
    plt.show()

print('manejar un sola unidad(mm, cm, m)')
f = float(input('ingrese el foco de el lente:\n')) #distancia focal
d = abs(float(input('distancia de el lente del objeto:\n'))) #a que distancia esta el lente?
h = float(input('altura del objeto respecto al eje axial: \n')) #altura de el lente
print(f'el objeto está a: {d}\nla distancia focal es: {f}')
print(f'el objeto está a: {d}\nla distancia focal es: {f}')
try:
    imagen = 1/((1/f)-(1/d))
    print(f'la imagen esta a: {imagen}')
except ZeroDivisionError:
    imagen = 0

magnificacion(f, d, h, imagen)
# Out:
# manejar un sola unidad(mm, cm, m)
# el objeto está a: 5.0
# la distancia focal es: 5.0
# el objeto está a: 5.0
# la distancia focal es: 5.0
# la magnificacion es: 0.0
# imagen en el infinito
# la altura del objeto: 5.0

# %% [markdown]
# ### version final de lentes y rayos en conjunto
#
# para que funciones bien es necesario que se cambie la pendiente del rayo incidente de el lente convergente, lo que solo cambiaria seria la coordenada del foco por donde pasa, no seria f sino -f

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def magnificacion(f, d, h, imagen):
    magnificacion = -imagen/d
    altura_imagen= h*magnificacion
    print(f'la magnificacion es: {magnificacion}')
    if f>0:
        grafica_lente_convergente(f, d, h, imagen, altura_imagen)
    elif f<0:
        grafica_lente_divergente(f, d, h, imagen, altura_imagen)
    else:
        print('como que cero mamahuevo!, digo glu,glu,glu,glu,glu')

def grafica_lente_convergente(f, d, h, imagen, altura_imagen):
    fig, ax = plt.subplots()
    
    # Crear Wedges{cuñás}
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-(R/2), 0), R, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge(((R/2), 0), R, 0, 360, color='aquamarine')
    
    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10, linewidth=0.7)  # Línea horizontal

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)
    
    #escala
    # ax.autoscale(tight=True)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente convergente.')

    # ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    # ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)
    if d > 4*h :
        ax.set_xlim(-5-abs(f) , 5+abs(f))
    else:
        ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    
    ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)
   
    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)

def grafica_lente_divergente(f, d, h, imagen, altura_imagen):
    fig, ax = plt.subplots()

    # Crear Wedges
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-R-0.5, 0), R, 0, 360, color='white')
    wedge_2 = mpatches.Wedge((R+0.5, 0), R, 0, 360, color='white')

    #crear cuadrado
    cuadrado_1 = plt.Polygon([[-3.85,-3.85], [-3.85,3.85], [3.85,3.85], [3.85,-3.85]], color = 'blue', alpha = 0.6)

    # Agregar el Wedge al gráfico
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10, linewidth=0.7)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10, linewidth=0.7)  # Línea horizontal

    #escala
    # ax.autoscale(tight=True)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente divergente.')

    if d > 4*h :
        ax.set_xlim(-5-abs(f) , 5+abs(f))
    else:
        ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    
    ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)
   
    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)


def rayos_incidentes(f, d, h,imagen):
    #rayo paralelo
    plt.plot([-abs(d), 0], [h, h], color = 'red', linewidth = 2.5)

    # pendiente del rayo que pasa por el foco
    x1, y1 = [-abs(d), -abs(f)], [h, 0]
    try:
        m_f = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_f=-500
        print('imagen en el infinito')

    # rayo que pasa por el foco
    x2 = [-abs(d), 0]
    y2 = [h, h + m_f * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='green', linewidth=2.5)

    # recta vertical en x=d
    x3 = [0,0]
    y3 = [-50, 50]
    plt.plot(x3, y3, color='k', linewidth=0.5, linestyle = '--')

    # cálculo de la intersección
    xi = 0
    yi = y2[0] + m_f * (xi - x2[0])
    interseccion = [xi, yi]

    # pendiente de la recta que pasa por el centro
    x1, y1 = [0, d], [h, 0]
    try:
        m_c = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_c = float('inf')
        print('Pendiente infinita')

    # recta que pasa por el centro
    x2 = [-d, 0]
    y2 = [h, h + m_c * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='blue', linewidth=2.5)
    
    #punto focal
    plt.plot(-abs(f), 0, marker = 'o', color = 'k')
    plt.plot(abs(f), 0, marker = 'o', color = 'k')

    # vector de altura h ubicado en el origen
    plt.quiver(-abs(d), 0, 0, h, angles='xy', scale_units='xy', scale=1, color='yellow')

    #agrego rayos emergentes
    rayos_emergentes(f, d, h, imagen, interseccion, m_c)

    plt.show()


def rayos_emergentes(f, d, h, imagen, list, m_centro):
    #rayo que pasa por el foco emerge paralelo
    plt.plot([-0, d+100], [list[1], list[1]], color = 'green', linewidth = 2.5)

    #proyeccion del rayo que pasa por el foco emerge paralelo
    plt.plot([-200, 200], [list[1], list[1]], color = 'green', linewidth = 2.5, linestyle = '--')
    
    # pendiente del rayo que emerge por el foco
    x1, y1 = [0, f], [h, 0]
    try:
        m = -(y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m=-500
        print('imagen en el infinito')

    # rayo que emerge por el foco
    x2 = [0, d + 50]
    y2 = [h, h - m * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='red', linewidth=2.5)

    # proyeccion del rayo que emerge por el foco
    x4 = [-200, 200]
    y4 = [h - m * (x4[0]), h - m * (x4[1])]
    plt.plot(x4, y4, color='red', linewidth=2.5, linestyle = '--')

    # rayo que emerge por el centro
    x_c= [0, d+50]
    y_c = [0, m_centro * (x_c[1] - x_c[0])]
    plt.plot(x_c, y_c, color='blue', linewidth=2.5)
    
    # proyeccion de el rayo que emerge por el centro
    x5 = [-200, 200]
    y5 = [ m_centro * (x5[0]), 0 + m_centro * (x5[1])]
    plt.plot(x5, y5, color='blue', linewidth=2.5, linestyle = '--')

    # Ecuación de la línea que emerge por el foco
    m1 = (y4[1] - y4[0]) / (x4[1] - x4[0])
    b1 = y4[0] - m1 * x4[0]

    # Ecuación del rayo que emerge por el centro
    m2 = (y5[1] - y5[0]) / (x5[1] - x5[0])
    b2 = y5[0] - m2 * x5[0]

    # Resolviendo para x
    try:
        x_intersect = (b2 - b1) / (m1 - m2)
        # Resolviendo para y
        y_intersect = m1 * x_intersect + b1

    except ZeroDivisionError:
        x_intersect = 0
        # Resolviendo para y
        y_intersect = 0

    #vector altura de la imagen
    plt.quiver(x_intersect, 0, 0, y_intersect, angles='xy', scale_units='xy', scale=1)
    print(f'la altura del objeto: {h}\n',f'altura de la imagen: {y_intersect}' if y_intersect != 0 else '') 

    #punto focal
    plt.show()

print('manejar un sola unidad(mm, cm, m)')
f = 16#float(input('ingrese el foco de el lente:\n')) #distancia focal
d = 13.5#abs(float(input('distancia de el lente del objeto:\n'))) #a que distancia esta el lente?
h = 5#float(input('altura del objeto respecto al eje axial: \n')) #altura de el lente
print(f'el objeto está a: {d}\nla distancia focal es: {f}')
try:
    imagen = 1/((1/f)-(1/d))
    print(f'la imagen esta a: {imagen}')
except ZeroDivisionError:
    imagen = 0

magnificacion(f, d, h, imagen)
# Out:
# manejar un sola unidad(mm, cm, m)
# el objeto está a: 13.5
# la distancia focal es: 16
# la imagen esta a: -86.40000000000003
# la magnificacion es: 6.400000000000002
# la altura del objeto: 5
#  altura de la imagen: 31.999999999999986

# %% [markdown]
# # VERSION FINAL DEL CODIGO CON CLASES

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def magnificacion(f, d, h, imagen):
    magnificacion = -imagen/d
    altura_imagen= h*magnificacion
    print(f'la magnificacion es: {magnificacion}')
    if f>0:
        grafica_lente_convergente(f, d, h, imagen, altura_imagen)
    elif f<0:
        grafica_lente_divergente(f, d, h, imagen, altura_imagen)
    else:
        print('como que cero mamahuevo!, digo glu,glu,glu,glu,glu')

def grafica_lente_convergente(f, d, h, imagen, altura_imagen):
    fig, ax = plt.subplots()
    
    # Crear Wedges{cuñás}
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-(R/2), 0), R, 0, 360, color='magenta', alpha = 0)
    wedge_2 = mpatches.Wedge(((R/2), 0), R, 0, 360, color='aquamarine')
    
    # Agregar el Wedge al gráfico
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10, linewidth=0.7)  # Línea horizontal

    # Recortar una cuña con la otra para mostrar la intersección
    wedge_2.set_clip_path(wedge_1)
    
    #escala
    # ax.autoscale(tight=True)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente convergente.')

    # ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    # ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)
    if d > 4*h :
        ax.set_xlim(-5-abs(f) , 5+abs(f))
    else:
        ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    
    ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)
   
    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)

def grafica_lente_divergente(f, d, h, imagen, altura_imagen):
    fig, ax = plt.subplots()

    # Crear Wedges
    div = 7
    R = (4*(6**2+5**2)**(1/2))/div
    wedge_1 = mpatches.Wedge((-R-0.5, 0), R, 0, 360, color='white')
    wedge_2 = mpatches.Wedge((R+0.5, 0), R, 0, 360, color='white')

    #crear cuadrado
    cuadrado_1 = plt.Polygon([[-3.85,-3.85], [-3.85,3.85], [3.85,3.85], [3.85,-3.85]], color = 'blue', alpha = 0.6)

    # Agregar el Wedge al gráfico
    ax.add_patch(cuadrado_1)
    ax.add_patch(wedge_1)
    ax.add_patch(wedge_2)

    # Agregar las líneas con alto valor de zorder
    # plt.axvline(x=0, color='k', zorder=10, linewidth=0.7)  # Línea vertical
    plt.axhline(y=0, color='k', zorder=10, linewidth=0.7)  # Línea horizontal

    #escala
    # ax.autoscale(tight=True)
    ax.set_aspect('equal')  # Para asegurar que se grafique simetricamente
    plt.title('sistema de lente divergente.')

    if d > 4*h :
        ax.set_xlim(-5-abs(f) , 5+abs(f))
    else:
        ax.set_xlim(-3-abs(imagen) if abs(imagen)+1 > abs(d) else -3-abs(d)  , 3+abs(imagen) if abs(imagen) > abs(d) else 3+abs(d)) if abs(imagen) <= 3*abs(h) else ax.set_xlim(-3-abs(d),3+abs(d)) 
    
    ax.set_ylim(-abs(h)-3 if abs(altura_imagen) < h else -3-abs(altura_imagen)  , abs(h)+3 if abs(altura_imagen) < h else 3+abs(altura_imagen)) if abs(altura_imagen)<=3*abs(imagen) else ax.set_ylim(-h-2, h+2)
   
    #agrego los rayos
    rayos_incidentes(f, d, h, imagen)


def rayos_incidentes(f, d, h,imagen):
    #rayo paralelo
    plt.plot([-abs(d), 0], [h, h], color = 'red', linewidth = 2.5)

    # pendiente del rayo que pasa por el foco
    x1, y1 = [-abs(d), -abs(f)], [h, 0]
    try:
        m_f = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_f=-500
        print('imagen en el infinito')

    # rayo que pasa por el foco
    x2 = [-abs(d), 0]
    y2 = [h, h + m_f * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='green', linewidth=2.5)

    # recta vertical en x=d
    x3 = [0,0]
    y3 = [-50, 50]
    plt.plot(x3, y3, color='k', linewidth=0.5, linestyle = '--')

    # cálculo de la intersección
    xi = 0
    yi = y2[0] + m_f * (xi - x2[0])
    interseccion = [xi, yi]

    # pendiente de la recta que pasa por el centro
    x1, y1 = [0, d], [h, 0]
    try:
        m_c = (y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m_c = float('inf')
        print('Pendiente infinita')

    # recta que pasa por el centro
    x2 = [-d, 0]
    y2 = [h, h + m_c * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='blue', linewidth=2.5)
    
    #punto focal
    plt.plot(-abs(f), 0, marker = 'o', color = 'k')
    plt.plot(abs(f), 0, marker = 'o', color = 'k')

    # vector de altura h ubicado en el origen
    plt.quiver(-abs(d), 0, 0, h, angles='xy', scale_units='xy', scale=1, color='yellow')

    #agrego rayos emergentes
    rayos_emergentes(f, d, h, imagen, interseccion, m_c)

    plt.show()


def rayos_emergentes(f, d, h, imagen, list, m_centro):
    #rayo que pasa por el foco emerge paralelo
    plt.plot([-0, d+100], [list[1], list[1]], color = 'green', linewidth = 2.5)

    #proyeccion del rayo que pasa por el foco emerge paralelo
    plt.plot([-200, 200], [list[1], list[1]], color = 'green', linewidth = 2.5, linestyle = '--')
    
    # pendiente del rayo que emerge por el foco
    x1, y1 = [0, f], [h, 0]
    try:
        m = -(y1[1] - y1[0]) / (x1[1] - x1[0])
    except ZeroDivisionError:
        m=-500
        print('imagen en el infinito')

    # rayo que emerge por el foco
    x2 = [0, d + 50]
    y2 = [h, h - m * (x2[1] - x2[0])]
    plt.plot(x2, y2, color='red', linewidth=2.5)

    # proyeccion del rayo que emerge por el foco
    x4 = [-200, 200]
    y4 = [h - m * (x4[0]), h - m * (x4[1])]
    plt.plot(x4, y4, color='red', linewidth=2.5, linestyle = '--')

    # rayo que emerge por el centro
    x_c= [0, d+50]
    y_c = [0, m_centro * (x_c[1] - x_c[0])]
    plt.plot(x_c, y_c, color='blue', linewidth=2.5)
    
    # proyeccion de el rayo que emerge por el centro
    x5 = [-200, 200]
    y5 = [ m_centro * (x5[0]), 0 + m_centro * (x5[1])]
    plt.plot(x5, y5, color='blue', linewidth=2.5, linestyle = '--')

    # Ecuación de la línea que emerge por el foco
    m1 = (y4[1] - y4[0]) / (x4[1] - x4[0])
    b1 = y4[0] - m1 * x4[0]

    # Ecuación del rayo que emerge por el centro
    m2 = (y5[1] - y5[0]) / (x5[1] - x5[0])
    b2 = y5[0] - m2 * x5[0]

    # Resolviendo para x
    try:
        x_intersect = (b2 - b1) / (m1 - m2)
        # Resolviendo para y
        y_intersect = m1 * x_intersect + b1

    except ZeroDivisionError:
        x_intersect = 0
        # Resolviendo para y
        y_intersect = 0

    #vector altura de la imagen
    plt.quiver(x_intersect, 0, 0, y_intersect, angles='xy', scale_units='xy', scale=1)
    print(f'la altura del objeto: {h}\n',f'altura de la imagen: {y_intersect}' if y_intersect != 0 else '') 

    #punto focal
    plt.show()

print('manejar un sola unidad(mm, cm, m)')
f = 5#float(input('ingrese el foco de el lente:\n')) #distancia focal
d = 5#abs(float(input('distancia de el lente del objeto:\n'))) #a que distancia esta el lente?
h = 5#float(input('altura del objeto respecto al eje axial: \n')) #altura de el lente
print(f'el objeto está a: {d}\nla distancia focal es: {f}')


try:
    imagen = 1/((1/f)-(1/d))
    print(f'la imagen esta a: {imagen}')
except ZeroDivisionError:
    imagen = 0

magnificacion(f, d, h, imagen)
# Out:
# manejar un sola unidad(mm, cm, m)
# el objeto está a: 5
# la distancia focal es: 5
# la magnificacion es: 0.0
# imagen en el infinito
# la altura del objeto: 5

# %%
class Lentes:
    def __init__(self, **kwargs):
        self.diccionario = kwargs
        
        opciones = {'f': 'foco', 'd': 'distancia de objeto', 'imagen': 'distancia imagen'}
        
        for clave, descripcion in opciones.items():
            if clave not in self.diccionario:
                print(f'Falta el valor de {descripcion}')
        
        if not any(opcion in self.diccionario for opcion in opciones):
            print('No se proporcionaron valores.')


    def calcular_faltante(self):
        resultado = {}
        
        try:
            if 'f' not in self.diccionario:
                d = self.diccionario['d']
                imagen = self.diccionario['imagen']
                f = 1 / (1 / d + 1 / imagen)
                resultado['f'] = f
                resultado['d'] = self.diccionario['d']
                resultado['imagen'] = self.diccionario['imagen']
                resultado['h'] = self.diccionario['h']
                print(f'el foco es: {f}')
            
            if 'd' not in self.diccionario:
                f = self.diccionario['f']
                imagen = self.diccionario['imagen']
                d = (f * imagen) / (imagen - f)
                resultado['f'] = self.diccionario['f']
                resultado['d'] = d
                resultado['imagen'] = self.diccionario['imagen']
                resultado['h'] = self.diccionario['h']
                print(f'El objeto está a: {d}')
            
            if 'imagen' not in self.diccionario:
                f = self.diccionario['f']
                d = self.diccionario['d']
                imagen = (f * d) / (d - f)
                resultado['f'] = self.diccionario['f']
                resultado['d'] = self.diccionario['d']
                resultado['imagen'] = imagen
                resultado['h'] = self.diccionario['h']
                print(f'la imagen esta a: {imagen}')
            
        except ZeroDivisionError:
            if 'd' not in self.diccionario:
                resultado['f'] = self.diccionario['f']
                resultado['d'] = 'oo'
                resultado['imagen'] = self.diccionario['imagen']
                resultado['h'] = self.diccionario['h']
                print(f'El objeto está ubicado muy lejos del lente, ya que la imagen está ubicada en el foco: {f}')
            if 'imagen' not in self.diccionario:
                resultado['f'] = self.diccionario['f']
                resultado['d'] = self.diccionario['d']
                resultado['imagen'] = 'oo'
                resultado['h'] = self.diccionario['h']
                print(f'La imagen está en el infinito ya que el objeto está en el foco: {d}')

        return resultado

'''se usara la siguiente seccion de codigo para la presentación'''
def valor_faltante():
    diccionario = {}
    print('manejar una sola unidad (mm, cm, m)')
    try:
        f = 5#input('ingrese el foco del lente (deje en blanco si falta):\n')
        if f:
            diccionario['f'] = float(f)
        d = 5#input('ingrese la distancia del lente al objeto (deje en blanco si falta):\n')
        if d:
            diccionario['d'] = abs(float(d))
        imagen = input('ingrese la distancia de la imagen al objeto (deje en blanco si falta):\n')
        if imagen:
            diccionario['imagen'] = float(imagen)
        h = 4#input('ingrese la altura del objeto (deje en blanco si falta):\n')
        if h:
            diccionario['h'] = float(h)
        return diccionario
    except ValueError:
        print('Ingrese valores válidos')
        return valor_faltante()


# def valor_faltante():
#     diccionario = {}
#     print('manejar una sola unidad (mm, cm, m)')

#     opciones = [('f', 'Ingrese el foco del lente (deje en blanco si falta): '),
#                ('d', 'Ingrese la distancia del lente al objeto (deje en blanco si falta): '),
#                ('imagen', 'Ingrese la imagen del objeto (deje en blanco si falta): '), 
#                ('h','Ingrese la altura del objeto: ')]

#     for clave, mensaje in opciones:
#         while True:
#             valor = input(mensaje)
#             if valor:
#                 try:
#                     diccionario[clave] = float(valor)
#                     break
#                 except ValueError:
#                     print('Ingrese un valor numérico válido.')
#             else:
#                 break
    
#     return diccionario



diccionario = valor_faltante()
print(diccionario)
lente = Lentes(**diccionario)
lente.calcular_faltante()

# %%
class Lentes:
    def __init__(self, **kwargs):
        self.diccionario = kwargs
        
        opciones = {'f': 'foco', 'd': 'distancia de objeto', 'imagen': 'distancia imagen'}
        
        for clave, descripcion in opciones.items():
            if clave not in self.diccionario:
                print(f'Falta el valor de {descripcion}')
        
        if not any(opcion in self.diccionario for opcion in opciones):
            print('No se proporcionaron valores.')


    def calcular_faltante(self):
        resultado = {}
        
        try:
            if 'f' not in self.diccionario:
                d = self.diccionario['d']
                imagen = self.diccionario['imagen']
                f = 1 / (1 / d + 1 / imagen)
                resultado['f'] = f
                resultado['d'] = self.diccionario['d']
                resultado['imagen'] = self.diccionario['imagen']
                resultado['h'] = self.diccionario['h']
                print(f'el foco es: {f}')
            
            if 'd' not in self.diccionario:
                f = self.diccionario['f']
                imagen = self.diccionario['imagen']
                d = (f * imagen) / (imagen - f)
                resultado['f'] = self.diccionario['f']
                resultado['d'] = d
                resultado['imagen'] = self.diccionario['imagen']
                resultado['h'] = self.diccionario['h']
                print(f'El objeto está a: {d}')
            
            if 'imagen' not in self.diccionario:
                f = self.diccionario['f']
                d = self.diccionario['d']
                imagen = (f * d) / (d - f)
                resultado['f'] = self.diccionario['f']
                resultado['d'] = self.diccionario['d']
                resultado['imagen'] = imagen
                resultado['h'] = self.diccionario['h']
                print(f'la imagen esta a: {imagen}')
            
        except ZeroDivisionError:
            if 'd' not in self.diccionario:
                resultado['f'] = self.diccionario['f']
                resultado['d'] = 'oo'
                resultado['imagen'] = self.diccionario['imagen']
                resultado['h'] = self.diccionario['h']
                print(f'El objeto está ubicado muy lejos del lente, ya que la imagen está ubicada en el foco: {f}')
            if 'imagen' not in self.diccionario:
                resultado['f'] = self.diccionario['f']
                resultado['d'] = self.diccionario['d']
                resultado['imagen'] = 'oo'
                resultado['h'] = self.diccionario['h']
                print(f'La imagen está en el infinito ya que el objeto está en el foco: {d}')

        return resultado

'''se usara la siguiente seccion de codigo para la presentación'''
def valor_faltante():
    diccionario = {}
    print('manejar una sola unidad (mm, cm, m)')
    try:
        f = 5#input('ingrese el foco del lente (deje en blanco si falta):\n')
        if f:
            diccionario['f'] = float(f)
        d = 5#input('ingrese la distancia del lente al objeto (deje en blanco si falta):\n')
        if d:
            diccionario['d'] = abs(float(d))
        imagen = input('ingrese la distancia de la imagen al objeto (deje en blanco si falta):\n')
        if imagen:
            diccionario['imagen'] = float(imagen)
        h = 4#input('ingrese la altura del objeto (deje en blanco si falta):\n')
        if h:
            diccionario['h'] = float(h)
        return diccionario
    except ValueError:
        print('Ingrese valores válidos')
        return valor_faltante()


# def valor_faltante():
#     diccionario = {}
#     print('manejar una sola unidad (mm, cm, m)')

#     opciones = [('f', 'Ingrese el foco del lente (deje en blanco si falta): '),
#                ('d', 'Ingrese la distancia del lente al objeto (deje en blanco si falta): '),
#                ('imagen', 'Ingrese la imagen del objeto (deje en blanco si falta): '), 
#                ('h','Ingrese la altura del objeto: ')]

#     for clave, mensaje in opciones:
#         while True:
#             valor = input(mensaje)
#             if valor:
#                 try:
#                     diccionario[clave] = float(valor)
#                     break
#                 except ValueError:
#                     print('Ingrese un valor numérico válido.')
#             else:
#                 break
    
#     return diccionario



diccionario = valor_faltante()
print(diccionario)
lente = Lentes(**diccionario)
lente.calcular_faltante()
# Out:
# manejar una sola unidad (mm, cm, m)
# {'f': 5.0, 'd': 5.0, 'h': 5.0}
# Falta el valor de distancia imagen
# La imagen está en el infinito ya que el objeto está en el foco: 5.0
# {'f': 5.0, 'd': 5.0, 'imagen': 'oo', 'h': 5.0}
